# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Vitals.csv")

# %%
df.head()
# Out:
#         0  Respiratory rate B/M  Heart Rate BPM Temperture
# 0  Case_1                    28              57     31.7oC
# 1  Case_2                    26              63     35.8oC
# 2  Case_3                    16              97     35.9oC

# %%
#plot Bar Graph
data = pd.DataFrame(df)

# %%
 fig = plt.figure()

# %%
ax = fig.add_axes([0,0,0,0.5])
x = list(df.iloc[:0])
y = list(df.iloc[:2])
ax.bar(x,y,color='b')
plt.show()

# %%
df.plot.bar
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting._core.PlotAccessor object at 0x15fe0c790>>

# %%
df.plot()
# Out:
# <Axes: >
